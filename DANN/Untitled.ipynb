# %%
import pandas as pd
from preprocess import prepare_df
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Function
from sklearn.metrics import r2_score

# %%
data = pd.read_csv('../lstm/utils/df_imputed.csv', index_col=0).drop(columns=['date'])

# %%
df_sensor_s, df_sensor_t, df_gpp_s, df_gpp_t, df_domain_s, df_domain_t, masks = prepare_df(data)

# %%
DEVICE = torch.device("cuda:" + str(1))

# %%
# Part 1: feature extraction
class CausalConv1d(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, dilation=1, **kwargs):
        super().__init__()
        self.pad = (kernel_size - 1) * dilation
        self.conv = nn.Conv1d(in_channels, out_channels, kernel_size, padding=self.pad, dilation=dilation, **kwargs)
    
    def forward(self, x):
        x = self.conv(x)
        return x[:, :, :-self.conv.padding[0]]

class ConvFeatureExtractor(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv_blocks = nn.Sequential(
            CausalConv1d(11, 32, 2),
            nn.ReLU(),
            CausalConv1d(32, 64, 2),
            nn.ReLU(),
            CausalConv1d(64, 128, 2),
        )
    def forward(self, x):
        return self.conv_blocks(x)

# %%
# top branch: regressor 
class RecurrentRegressor(nn.Module):
    # gets a sequence of shape (seq len, batch size, n_channels)
    def __init__(self, input_dim, hidden_dim, num_layers, bidirectional):
        super().__init__()
        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.num_layers = num_layers
        self.bidirectional = bidirectional
        self.num_directions = 2 if self.bidirectional else 1

        self.rnn = nn.LSTM(input_size=input_dim, hidden_size=hidden_dim, num_layers=num_layers, bidirectional=bidirectional)
        self.fc = nn.Sequential(
            nn.Linear(self.num_directions * hidden_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
        )

    def forward(self, x):
        output, (h, c) = self.rnn(x)
        # output: seq_len, batch, num_directions * hidden_size
        T, N, C = output.shape
        output = output.view(T*N, -1) # seq_len * batch, num_directions * hidden_size
        output = self.fc(output).view(T, N, -1) #  seq_len, batch, 1
        return output

# %%
# one domain discriminator for every source domain
class DomainClassifier(nn.Module):
    # gets a sequence of shape (seq len, batch size, n_channels) --> (batch_size, seq_len * n_channels)
    def __init__(self, n_channels):
        super().__init__()
        self.n_channels = n_channels
        self.fc = nn.Sequential(
            nn.Linear(n_channels, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )
    def forward(self, x):
        # x: (seq len, batch size, n_channels)
        # average over the seq_len dim
        x = torch.mean(x, dim=1) # x: (batch_size, n_channels)
        y_pred = self.fc(x)
        return y_pred

# %%
class ReverseLayerF(Function):
    @staticmethod
    def forward(ctx, x, alpha):
        ctx.alpha = alpha

        return x.view_as(x)

    @staticmethod
    def backward(ctx, grad_output):
        output = grad_output.neg() * ctx.alpha

        return output, None

# %%
class Model(nn.Module):
    def __init__(self, extractor, regressor, classifiers):
        super().__init__()
        self.extractor = extractor
        self.regressor = regressor
        self.classifiers = classifiers

    def forward(self, s, t, alpha):
        s = s.permute(0, 2, 1)
        t = t.permute(0, 2, 1)

        s_features = self.extractor(s)
        t_features = self.extractor(t)
        
        s_features = s_features.permute(2, 0, 1)
        t_features = t_features.permute(2, 0, 1)
        y_pred = self.regressor(s_features)
        
        rev_s_features = ReverseLayerF.apply(s_features, alpha)
        rev_t_features = ReverseLayerF.apply(t_features, alpha)
    
        s_preds = []
        t_preds = []

        for classifier in self.classifiers:
            s_domain_pred = classifier(rev_s_features)
            t_domain_pred = classifier(rev_t_features)
            s_preds.append(s_domain_pred)
            t_preds.append(t_domain_pred)

        return y_pred, s_preds, t_preds

# %%
def loss_fn(source_domains, target_domains, y, source_preds, target_preds, y_pred, mu):
    reg_loss = nn.MSELoss()(y_pred, y)
    domain_losses = []
    for i in range(9):
        loss2 = nn.BCELoss()(source_preds[i].squeeze(0), source_domains)
        loss3 = nn.BCELoss()(target_preds[i].squeeze(0), target_domains)
        domain_losses.append(loss2 + loss3)
    domain_loss = mu * torch.mean(torch.tensor(domain_losses))
    loss = reg_loss + domain_loss
    return loss, domain_loss, reg_loss

# %%
DOMAINS = 9
feature_extractor = ConvFeatureExtractor()
regressor = RecurrentRegressor(128, 128, 1, False)
classifiers = []
for t in range(DOMAINS):
    classifiers.append(DomainClassifier(128).to(DEVICE))

model = Model(feature_extractor, regressor, classifiers).to(DEVICE)
optimizer = torch.optim.RMSprop(model.parameters())

# %%
import pdb
EPOCHS = 1000
alpha = 0.1
for epoch in range(EPOCHS):
    train_loss = 0.0
    train_reg_loss = 0.0
    train_domain_loss = 0.0
    train_r2 = 0.0
    model.train()
    for t in range(len(df_sensor_t)):
        domain_losses = []
        x_t = torch.FloatTensor(df_sensor_t[t].values).unsqueeze(1).to(DEVICE)
        y_t = torch.FloatTensor(df_gpp_t[t].values).to(DEVICE)
        domain_t  = torch.FloatTensor([1]).to(DEVICE)
        for k in range(DOMAINS):
          s_k = np.random.choice(range(len(df_sensor_s[k])))
          x_s  = torch.FloatTensor(df_sensor_s[k][s_k].values).unsqueeze(1).to(DEVICE)
          y_s  = torch.FloatTensor(df_gpp_s[k][s_k].values).to(DEVICE)
          domain_s = torch.FloatTensor([0]).to(DEVICE)

          y_pred, s_preds, t_preds = model(x_s, x_t, alpha)
          y_pred = y_pred.squeeze()
          # Get loss and update
          optimizer.zero_grad()

          loss = loss_fn(domain_s, domain_t, y_s, s_preds, t_preds, y_pred, 1)
          domain_losses.append(loss)
          train_r2 += r2_score(y_true=y_s.detach().cpu(), y_pred=y_pred.detach().cpu())


        worst_domain = torch.tensor(domain_losses).argmin(axis=0)[1]
        loss = domain_losses[worst_domain][0]
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        train_domain_loss += domain_losses[worst_domain][1].item()
        train_reg_loss += domain_losses[worst_domain][2].item()

    
    train_loss /= len(df_sensor_t)
    train_domain_loss /=  len(df_sensor_t)
    train_reg_loss /= len(df_sensor_t)
    train_r2 /= len(df_sensor_t)*DOMAINS
    print(f"Epoch: {epoch+1}/{EPOCHS}")
    print(f"Train loss: {train_loss:.4f} | Reg loss: {train_reg_loss:.4f} | Domain loss: {train_domain_loss:.4f} | R2: {train_r2:.4f}")
# Out:
# Epoch: 1/1000
# Train loss: 40.4315 | Reg loss: 38.8818 | Domain loss: 1.5497 | R2: -37.7259
# Epoch: 2/1000
# Train loss: 2.5957 | Reg loss: 0.9997 | Domain loss: 1.5960 | R2: 0.0000
# Epoch: 3/1000
# Train loss: 2.5960 | Reg loss: 0.9996 | Domain loss: 1.5964 | R2: 0.0000
# Epoch: 4/1000
# Train loss: 2.5954 | Reg loss: 0.9994 | Domain loss: 1.5961 | R2: 0.0000
# Epoch: 5/1000
# Train loss: 2.5950 | Reg loss: 0.9996 | Domain loss: 1.5954 | R2: 0.0000
# Epoch: 6/1000
# Train loss: 2.5977 | Reg loss: 0.9997 | Domain loss: 1.5980 | R2: 0.0000
# Epoch: 7/1000
# Train loss: 2.5953 | Reg loss: 0.9998 | Domain loss: 1.5955 | R2: 0.0000
# Epoch: 8/1000
# Train loss: 2.5977 | Reg loss: 0.9996 | Domain loss: 1.5981 | R2: 0.0000
# Epoch: 9/1000
# Train loss: 2.5945 | Reg loss: 0.9997 | Domain loss: 1.5948 | R2: 0.0000
# Epoch: 10/1000
# Train loss: 2.5952 | Reg loss: 0.9996 | Domain loss: 1.5956 | R2: 0.0000
# Epoch: 11/1000
# Train loss: 2.5960 | Reg loss: 0.9996 | Domain loss: 1.5964 | R2: -0.0000
# Epoch: 12/1000
# Train loss: 2.5963 | Reg loss: 0.9995 | Domain loss: 1.5968 | R2: -0.0000
# Epoch: 13/1000
# Train loss: 2.5977 | Reg loss: 0.9994 | Domain loss: 1.5983 | R2: -0.0001
# Epoch: 14/1000
# Train loss: 2.5950 | Reg loss: 0.9995 | Domain loss: 1.5954 | R2: -0.0002
# Epoch: 15/1000
# Train loss: 2.5957 | Reg loss: 0.9995 | Domain loss: 1.5962 | R2: -0.0002
# Epoch: 16/1000
# Train loss: 2.5974 | Reg loss: 0.9993 | Domain loss: 1.5981 | R2: -0.0003
# Epoch: 17/1000
# Train loss: 2.5972 | Reg loss: 0.9994 | Domain loss: 1.5979 | R2: -0.0004
# Epoch: 18/1000
# Train loss: 2.5954 | Reg loss: 0.9993 | Domain loss: 1.5961 | R2: -0.0003
# Epoch: 19/1000
# Train loss: 2.5961 | Reg loss: 0.9995 | Domain loss: 1.5965 | R2: -0.0006
# Epoch: 20/1000
# Train loss: 2.5972 | Reg loss: 0.9999 | Domain loss: 1.5973 | R2: -0.0023
# Epoch: 21/1000
# Train loss: 2.5970 | Reg loss: 0.9993 | Domain loss: 1.5977 | R2: -0.0005
# Epoch: 22/1000
# Train loss: 2.5913 | Reg loss: 0.9981 | Domain loss: 1.5932 | R2: -0.0038
# Epoch: 23/1000
# Train loss: 2.5897 | Reg loss: 0.9995 | Domain loss: 1.5902 | R2: 0.0000
# Epoch: 24/1000
# Train loss: 2.5888 | Reg loss: 0.9997 | Domain loss: 1.5891 | R2: 0.0000
# Epoch: 25/1000
# Train loss: 2.5889 | Reg loss: 0.9997 | Domain loss: 1.5892 | R2: 0.0000
# Epoch: 26/1000
# Train loss: 2.5900 | Reg loss: 0.9997 | Domain loss: 1.5903 | R2: -0.0000
# Epoch: 27/1000
# Train loss: 2.5883 | Reg loss: 0.9998 | Domain loss: 1.5886 | R2: 0.0000
# Epoch: 28/1000
# Train loss: 2.5901 | Reg loss: 0.9997 | Domain loss: 1.5904 | R2: 0.0000
# Epoch: 29/1000
# Train loss: 2.5894 | Reg loss: 0.9994 | Domain loss: 1.5901 | R2: -0.0001
# Epoch: 30/1000
# Train loss: 2.5882 | Reg loss: 0.9993 | Domain loss: 1.5890 | R2: -0.0001
# Epoch: 31/1000
# Train loss: 2.5835 | Reg loss: 0.9977 | Domain loss: 1.5858 | R2: -0.0002
# Epoch: 32/1000
# Train loss: 2.5771 | Reg loss: 0.9981 | Domain loss: 1.5790 | R2: -0.0021
# Epoch: 33/1000
# Train loss: 2.5228 | Reg loss: 0.9549 | Domain loss: 1.5679 | R2: -0.0120
# Epoch: 34/1000
# Train loss: 2.3989 | Reg loss: 0.8446 | Domain loss: 1.5543 | R2: 0.1360
# Epoch: 35/1000
# Train loss: 2.1849 | Reg loss: 0.6527 | Domain loss: 1.5322 | R2: 0.3140
# Epoch: 36/1000
# Train loss: 2.1036 | Reg loss: 0.6059 | Domain loss: 1.4978 | R2: 0.3233
# Epoch: 37/1000
# Train loss: 1.9989 | Reg loss: 0.5187 | Domain loss: 1.4802 | R2: 0.3174
# Epoch: 38/1000
# Train loss: 1.9561 | Reg loss: 0.4903 | Domain loss: 1.4658 | R2: 0.3723
# Epoch: 39/1000
# Train loss: 1.9274 | Reg loss: 0.4624 | Domain loss: 1.4650 | R2: 0.3538
# Epoch: 40/1000
# Train loss: 1.9621 | Reg loss: 0.4950 | Domain loss: 1.4671 | R2: 0.3834
# Epoch: 41/1000
# Train loss: 1.9520 | Reg loss: 0.4891 | Domain loss: 1.4630 | R2: 0.3906
# Epoch: 42/1000
# Train loss: 1.9225 | Reg loss: 0.4662 | Domain loss: 1.4562 | R2: 0.3711
# Epoch: 43/1000
# Train loss: 1.9047 | Reg loss: 0.4518 | Domain loss: 1.4528 | R2: 0.3495
# Epoch: 44/1000
# Train loss: 1.9197 | Reg loss: 0.4691 | Domain loss: 1.4506 | R2: 0.3382
# Epoch: 45/1000
# Train loss: 1.8945 | Reg loss: 0.4483 | Domain loss: 1.4462 | R2: 0.3666
# Epoch: 46/1000
# Train loss: 1.8536 | Reg loss: 0.4023 | Domain loss: 1.4512 | R2: 0.3200
# Epoch: 47/1000
# Train loss: 1.8793 | Reg loss: 0.4328 | Domain loss: 1.4464 | R2: 0.3369
# Epoch: 48/1000
# Train loss: 1.8723 | Reg loss: 0.4300 | Domain loss: 1.4423 | R2: 0.3659
# Epoch: 49/1000
# Train loss: 1.8644 | Reg loss: 0.4235 | Domain loss: 1.4409 | R2: 0.3566
# Epoch: 50/1000
# Train loss: 1.8820 | Reg loss: 0.4399 | Domain loss: 1.4420 | R2: 0.3268
# Epoch: 51/1000
# Train loss: 1.8608 | Reg loss: 0.4180 | Domain loss: 1.4428 | R2: 0.3677
# Epoch: 52/1000
# Train loss: 1.8430 | Reg loss: 0.3991 | Domain loss: 1.4438 | R2: 0.3217
# Epoch: 53/1000
# Train loss: 1.8696 | Reg loss: 0.4340 | Domain loss: 1.4357 | R2: 0.3553
# Epoch: 54/1000
# Train loss: 1.8414 | Reg loss: 0.4065 | Domain loss: 1.4349 | R2: 0.3482
# Epoch: 55/1000
# Train loss: 1.8331 | Reg loss: 0.4004 | Domain loss: 1.4327 | R2: 0.3548
# Epoch: 56/1000
# Train loss: 1.8330 | Reg loss: 0.3975 | Domain loss: 1.4355 | R2: 0.3310
# Epoch: 57/1000
# Train loss: 1.8002 | Reg loss: 0.3669 | Domain loss: 1.4334 | R2: 0.2921
# Epoch: 58/1000
# Train loss: 1.8145 | Reg loss: 0.3853 | Domain loss: 1.4291 | R2: 0.3193
# Epoch: 59/1000
# Train loss: 1.7674 | Reg loss: 0.3379 | Domain loss: 1.4295 | R2: 0.2871
# Epoch: 60/1000
# Train loss: 1.8318 | Reg loss: 0.4029 | Domain loss: 1.4289 | R2: 0.3100
# Epoch: 61/1000
# Train loss: 1.8120 | Reg loss: 0.3820 | Domain loss: 1.4300 | R2: 0.3281
# Epoch: 62/1000
# Train loss: 1.8295 | Reg loss: 0.3992 | Domain loss: 1.4303 | R2: 0.3278
# Epoch: 63/1000
# Train loss: 1.8191 | Reg loss: 0.3892 | Domain loss: 1.4299 | R2: 0.3277
# Epoch: 64/1000
# Train loss: 1.7839 | Reg loss: 0.3534 | Domain loss: 1.4304 | R2: 0.3382
# Epoch: 65/1000
# Train loss: 1.7851 | Reg loss: 0.3557 | Domain loss: 1.4294 | R2: 0.3106
# Epoch: 66/1000
# Train loss: 1.8241 | Reg loss: 0.3962 | Domain loss: 1.4279 | R2: 0.3343
# Epoch: 67/1000
# Train loss: 1.7663 | Reg loss: 0.3401 | Domain loss: 1.4262 | R2: 0.3506
# Epoch: 68/1000
# Train loss: 1.7935 | Reg loss: 0.3672 | Domain loss: 1.4263 | R2: 0.2930
# Epoch: 69/1000
# Train loss: 1.6978 | Reg loss: 0.2741 | Domain loss: 1.4237 | R2: 0.3200
# Epoch: 70/1000
# Train loss: 1.7119 | Reg loss: 0.2845 | Domain loss: 1.4274 | R2: 0.2300
# Epoch: 71/1000
# Train loss: 1.7334 | Reg loss: 0.3091 | Domain loss: 1.4243 | R2: 0.2358
# Epoch: 72/1000
# Train loss: 1.7035 | Reg loss: 0.2814 | Domain loss: 1.4221 | R2: 0.2569
# Epoch: 73/1000
# Train loss: 2.0230 | Reg loss: 0.5636 | Domain loss: 1.4594 | R2: 0.2405
# Epoch: 74/1000
# Train loss: 1.8532 | Reg loss: 0.4120 | Domain loss: 1.4412 | R2: 0.3376
# Epoch: 75/1000
# Train loss: 1.7607 | Reg loss: 0.3225 | Domain loss: 1.4382 | R2: 0.3190
# Epoch: 76/1000
# Train loss: 1.7815 | Reg loss: 0.3472 | Domain loss: 1.4343 | R2: 0.2875
# Epoch: 77/1000
# Train loss: 1.7399 | Reg loss: 0.3128 | Domain loss: 1.4271 | R2: 0.3176
# Epoch: 78/1000
# Train loss: 1.7825 | Reg loss: 0.3531 | Domain loss: 1.4294 | R2: 0.3343
# Epoch: 79/1000
# Train loss: 1.7395 | Reg loss: 0.3132 | Domain loss: 1.4264 | R2: 0.3104
# Epoch: 80/1000
# Train loss: 1.7361 | Reg loss: 0.3090 | Domain loss: 1.4271 | R2: 0.3535
# Epoch: 81/1000
# Train loss: 1.7243 | Reg loss: 0.2938 | Domain loss: 1.4305 | R2: 0.2812
# Epoch: 82/1000
# Train loss: 1.7728 | Reg loss: 0.3522 | Domain loss: 1.4206 | R2: 0.2947
# Epoch: 83/1000
# Train loss: 1.7822 | Reg loss: 0.3612 | Domain loss: 1.4210 | R2: 0.3509
# Epoch: 84/1000
# Train loss: 1.7976 | Reg loss: 0.3712 | Domain loss: 1.4264 | R2: 0.3305
# Epoch: 85/1000
# Train loss: 1.7274 | Reg loss: 0.2996 | Domain loss: 1.4278 | R2: 0.3431
# Epoch: 86/1000
# Train loss: 1.7567 | Reg loss: 0.3259 | Domain loss: 1.4308 | R2: 0.3222
# Epoch: 87/1000
# Train loss: 1.7138 | Reg loss: 0.2822 | Domain loss: 1.4316 | R2: 0.2534
# Epoch: 88/1000
# Train loss: 1.7052 | Reg loss: 0.2729 | Domain loss: 1.4323 | R2: 0.2421
# Epoch: 89/1000
# Train loss: 1.8221 | Reg loss: 0.3904 | Domain loss: 1.4316 | R2: 0.3777
# Epoch: 90/1000
# Train loss: 1.8346 | Reg loss: 0.4103 | Domain loss: 1.4243 | R2: 0.3701
# Epoch: 91/1000
# Train loss: 1.7246 | Reg loss: 0.3063 | Domain loss: 1.4182 | R2: 0.3358
# Epoch: 92/1000
# Train loss: 1.7773 | Reg loss: 0.3504 | Domain loss: 1.4269 | R2: 0.3631
# Epoch: 93/1000
# Train loss: 1.7914 | Reg loss: 0.3635 | Domain loss: 1.4279 | R2: 0.3346
# Epoch: 94/1000
# Train loss: 1.8321 | Reg loss: 0.4050 | Domain loss: 1.4271 | R2: 0.3895
# Epoch: 95/1000
# Train loss: 1.7607 | Reg loss: 0.3284 | Domain loss: 1.4323 | R2: 0.3548
# Epoch: 96/1000
# Train loss: 1.7667 | Reg loss: 0.3354 | Domain loss: 1.4313 | R2: 0.3364
# Epoch: 97/1000
# Train loss: 1.7231 | Reg loss: 0.2891 | Domain loss: 1.4340 | R2: 0.3364
# Epoch: 98/1000
# Train loss: 1.7519 | Reg loss: 0.3205 | Domain loss: 1.4314 | R2: 0.2971
# Epoch: 99/1000
# Train loss: 1.6858 | Reg loss: 0.2509 | Domain loss: 1.4349 | R2: 0.3059
# Epoch: 100/1000
# Train loss: 1.6847 | Reg loss: 0.2542 | Domain loss: 1.4305 | R2: 0.2636
# Epoch: 101/1000
# Train loss: 1.6892 | Reg loss: 0.2579 | Domain loss: 1.4313 | R2: 0.2795
# Epoch: 102/1000
# Train loss: 1.8563 | Reg loss: 0.4247 | Domain loss: 1.4317 | R2: 0.3758
# Epoch: 103/1000
# Train loss: 1.7371 | Reg loss: 0.2986 | Domain loss: 1.4386 | R2: 0.3894
# Epoch: 104/1000
# Train loss: 1.8132 | Reg loss: 0.3749 | Domain loss: 1.4383 | R2: 0.3900
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-209-aa000354a0d7> in <module>
#      24           optimizer.zero_grad()
#      25
# ---> 26           loss = loss_fn(domain_s, domain_t, y_s, s_preds, t_preds, y_pred, 1)
#      27           domain_losses.append(loss)
#      28           train_r2 += r2_score(y_true=y_s.detach().cpu(), y_pred=y_pred.detach().cpu())
#
# <ipython-input-205-f57f5cd4610e> in loss_fn(source_domains, target_domains, y, source_preds, target_preds, y_pred, mu)
#       3     domain_losses = []
#       4     for i in range(9):
# ----> 5         loss2 = nn.BCELoss()(source_preds[i].squeeze(0), source_domains)
#       6         loss3 = nn.BCELoss()(target_preds[i].squeeze(0), target_domains)
#       7         domain_losses.append(loss2 + loss3)
#
# ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/nn/modules/loss.py in forward(self, input, target)
#     611     def forward(self, input: Tensor, target: Tensor) -> Tensor:
#     612         assert self.weight is None or isinstance(self.weight, Tensor)
# --> 613         return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
#     614
#     615
#
# ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/nn/functional.py in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    2760         weight = weight.expand(new_size)
#    2761
# -> 2762     return torch._C._nn.binary_cross_entropy(input, target, weight, reduction_enum)
#    2763
#    2764
#
# KeyboardInterrupt:

# %%
y_pred, s_preds, t_preds = model(x_s, x_t, alpha)
y_pred = y_pred.squeeze()

# %%
x_s.shape
# Out:
# torch.Size([5479, 1, 11])

# %%
from plotly import graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(y=y_s.detach().cpu(),
                    mode='markers',
                    name='gt', 
                    marker=dict(size=3)))

fig.add_trace(go.Scatter(y=y_pred.detach().cpu(),
                    mode='markers',
                    name='pred', 
                    marker=dict(size=3)))
# Out:
# <div>                            <div id="a909fe2f-1f7c-40ed-80e0-f9a50616d1a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a909fe2f-1f7c-40ed-80e0-f9a50616d1a9")) {                    Plotly.newPlot(                        "a909fe2f-1f7c-40ed-80e0-f9a50616d1a9",                        [{"marker": {"size": 3}, "mode": "markers", "name": "gt", "type": "scatter", "y": [-0.6360599398612976, -0.599965512752533, -0.5993053913116455, -0.6313974857330322, -0.6093757748603821, -0.6310970187187195, -0.6310211420059204, -0.5994701385498047, -0.6675043106079102, -0.6480187773704529, -0.6017972230911255, -0.562804639339447, -0.5163516998291016, -0.6366106867790222, -0.5904381275177002, -0.6865332722663879, -0.6270061731338501, -0.63857501745224, -0.6680557131767273, -0.6488888263702393, -0.6754477620124817, -0.6141164898872375, -0.6519410014152527, -0.6254385709762573, -0.5124198198318481, -0.4445233941078186, -0.5818243026733398, -0.4368281662464142, -0.5610021948814392, -0.5077657699584961, -0.5193098187446594, -0.49776268005371094, -0.5792478322982788, -0.6644399166107178, -0.6142308115959167, -0.4689936935901642, -0.42472198605537415, -0.45589691400527954, -0.32703086733818054, -0.4626907408237457, -0.2592388987541199, -0.35402774810791016, -0.3716484308242798, -0.29202499985694885, -0.2055700570344925, -0.6363880634307861, -0.0696294903755188, -0.5602403283119202, -0.3986649215221405, -0.3963034152984619, -0.3420872986316681, -0.5941214561462402, -0.38657182455062866, -0.34182342886924744, -0.4845066964626312, -0.41470691561698914, -0.44617512822151184, -0.4096568524837494, -0.38729792833328247, -0.37658292055130005, -0.3562191426753998, -0.43076634407043457, -0.49365654587745667, -0.44507527351379395, -0.5114587545394897, -0.5958265066146851, -0.38494953513145447, -0.33247125148773193, -0.02129722759127617, -0.2350238710641861, -0.32783764600753784, -0.5059565901756287, 0.002862492809072137, -0.10237099230289459, -0.17845980823040009, -0.4484919309616089, -0.172221377491951, -0.20429664850234985, 0.07475819438695908, -0.4751274883747101, -0.22734896838665009, -0.3762056827545166, -0.08038274943828583, -0.5247817635536194, -0.3383084535598755, -0.1993665099143982, -0.21308791637420654, -0.35331428050994873, -0.591220498085022, -0.16158270835876465, 1.4735620021820068, -0.012877109460532665, -0.38899001479148865, -0.10753137618303299, -0.40127769112586975, 0.521818995475769, 0.6673111915588379, 0.868196964263916, 0.7351271510124207, 0.6089782118797302, 0.49536722898483276, 1.0230413675308228, 0.801408052444458, 0.6751893162727356, 0.37056151032447815, 0.8907325267791748, 0.33968114852905273, 0.7815086841583252, 1.0790281295776367, 1.1714379787445068, 0.635283887386322, 0.9615467190742493, 1.545746088027954, 1.3460661172866821, 0.4430939257144928, 1.2179962396621704, 1.2957552671432495, 0.6615437269210815, 1.9393277168273926, 1.8724080324172974, 2.204150438308716, 1.9972639083862305, 2.3032326698303223, 2.5007212162017822, 0.4514801502227783, 0.15152950584888458, 0.7368214130401611, 2.629981756210327, 2.260145902633667, 2.6015915870666504, 2.791055917739868, 2.854661226272583, 2.893714189529419, 2.961397171020508, 2.9339663982391357, 2.386331796646118, 1.8033949136734009, 2.405520439147949, 2.803571939468384, 2.2235608100891113, 1.3634095191955566, 3.004941940307617, 3.048595666885376, 2.1736059188842773, 3.13141131401062, 1.566292643547058, 2.3272836208343506, 1.527495265007019, 2.582730293273926, 2.9567744731903076, 2.024738311767578, 2.0985047817230225, 1.4326541423797607, 2.3080079555511475, 1.6516315937042236, 2.0579257011413574, 2.117824077606201, 2.049726963043213, 1.7062969207763672, 2.602158546447754, 0.8064755201339722, 2.5505895614624023, 1.9228649139404297, 2.666461706161499, 2.1728818 ...

# %%
for i in range(len(df_sensor_s)):
    print(len(df_sensor_s[i]))
# Out:
# 14
# 1
# 3
# 3
# 4
# 5
# 2
# 9
# 1
