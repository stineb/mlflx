# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import random
import time
import math
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms
import matplotlib.pyplot as plt
from torch.nn.utils.rnn import pad_sequence
import torch.nn.functional as F
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence, pad_sequence
from preprocess import prepare_df
from sklearn.metrics import r2_score

# %%
data = pd.read_csv('../data/df_final.csv', index_col=0).drop(columns=['lat', 'lon', 'elv','date','c4','whc'])
good_sites = pd.read_csv("../data/df_20210507.csv", low_memory=False )['sitename'].unique()

# %%
df_sensor, df_meta, df_gpp = prepare_df(data,sites=good_sites)

# %%
sites_to_train = list(range(len(df_sensor)))
sites_to_train.remove(0)
sites_to_test = [0]

x_train = [pd.concat((df_sensor[i], df_meta[i]), axis=1).values for i in sites_to_train]
conditional_train = [df_meta[i].values for i in sites_to_train]
y_train = [df_gpp[i].values.reshape(-1,1) for i in sites_to_train]

x_test = [pd.concat((df_sensor[i],df_meta[i]), axis=1).values for i in sites_to_test]
conditional_test = [df_meta[i].values for i in sites_to_test]
y_test = [df_gpp[i].values.reshape(-1,1) for i in sites_to_test]

# %%
class Encoder(nn.Module):
    def __init__(self, input_features, output_features):
        super().__init__()
        self.input_features = input_features
        self.output_features = output_features

        self.rnn = nn.LSTM(input_size=input_features, hidden_size=output_features)
    
    def forward(self, x):
        outputs, (h, c) = self.rnn(x)

        return outputs.squeeze(1) #shape=(seq_len, num_dir * output_features)

class Reparametrize(nn.Module):
    def __init__(self, encoder_output, latent_size):
        super().__init__()
        self.encoder_output = encoder_output
        self.latent_size = latent_size

        self.fc_to_mean = nn.Linear(encoder_output, latent_size)
        self.fc_to_logvar = nn.Linear(encoder_output, latent_size)

        self.fc_to_r_mean = nn.Linear(encoder_output, 1)
        self.fc_to_r_logvar = nn.Linear(encoder_output, 1)

        self.fc_r_to_pzmean = nn.Linear(1, latent_size)

        nn.init.xavier_uniform_(self.fc_to_mean.weight)
        nn.init.xavier_uniform_(self.fc_to_logvar.weight)
        nn.init.xavier_uniform_(self.fc_to_r_mean.weight)
        nn.init.xavier_uniform_(self.fc_to_r_logvar.weight)

    def forward(self, x):
        self.mean = self.fc_to_mean(x)
        self.logvar = self.fc_to_logvar(x)

        self.r_mean = self.fc_to_r_mean(x)
        self.r_logvar = self.fc_to_r_logvar(x)

        std = torch.exp(0.5 * self.logvar)
        eps = torch.randn_like(std)
        z = eps.mul(std).add_(self.mean)

        std = torch.exp(0.5 * self.r_logvar)
        eps = torch.randn_like(std)
        r = eps.mul(std).add_(self.r_mean)

        return z, self.mean, self.logvar, self.fc_r_to_pzmean(r), self.r_mean, self.r_logvar

class Decoder(nn.Module):
    def __init__(self, input_features, output_features):
        super().__init__()
        self.input_features = input_features
        self.output_features = output_features

        self.rnn = nn.LSTM(input_size=input_features, hidden_size=output_features)

        self.rnn_to_output = nn.Sequential(
            nn.Linear(self.output_features, self.output_features),
            nn.Tanh(),
            nn.Linear(self.output_features, self.output_features),
        )

    def forward(self, x):
        outputs, (h, c) = self.rnn(x)
        outputs = outputs.squeeze(1)
        return self.rnn_to_output(outputs) #shape=(seq_len, num_dir * output_features)

class Model(nn.Module):
    def __init__(self, encoder, decoder, reparam):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.reparam = reparam

    def forward(self, x, conditional):
        x = self.encoder(x) # x has the conditional
        z, mean, logvar, pz_mean, r_mean, r_logvar = self.reparam(x)

        # concat the conditoinal to z
        z1 = torch.cat([z, conditional], dim=1)
        
        # decode
        x = self.decoder(z1.unsqueeze(1))

        return x, mean, logvar, pz_mean, r_mean, r_logvar

# %%
def loss_fn(x_decoded, x, mu, logvar, w, pz_mean, r_mean, r_logvar, r_input):
    kl_loss = w * (-0.5) * torch.mean(1 + logvar - (mu - pz_mean).pow(2) - logvar.exp())
    recon_loss = F.mse_loss(x_decoded, x)
    label_loss = torch.mean(0.5 * (r_mean - r_input).pow(2) / r_logvar.exp() + 0.5 * r_logvar)
    return kl_loss + recon_loss + label_loss, kl_loss, recon_loss, label_loss

# %%
ENCODER_INPUT_DIM = x_train[0].shape[1]
ENCODER_OUTPUT_DIM = 16
REPARAM_INPUT_DIM = ENCODER_OUTPUT_DIM
LATENT_DIM = 64
REPARAM_OUTPUT_DIM = LATENT_DIM
DECODER_INPUT_DIM = LATENT_DIM + conditional_train[0].shape[1]
DECODER_OUTPUT_DIM = len(df_sensor[0].columns)

DEVICE = 'cuda:7'

encoder = Encoder(ENCODER_INPUT_DIM, ENCODER_OUTPUT_DIM).to(DEVICE)
decoder = Decoder(DECODER_INPUT_DIM, DECODER_OUTPUT_DIM).to(DEVICE)
reparam = Reparametrize(REPARAM_INPUT_DIM, REPARAM_OUTPUT_DIM).to(DEVICE)
model = Model(encoder, decoder, reparam).to(DEVICE)

optimizer = torch.optim.Adam(model.parameters(), lr=3e-4)

# %%
EPOCHS = 200
for epoch in range(EPOCHS):
    train_loss = 0.0
    train_kl_loss = 0.0
    train_recon_loss = 0.0
    train_label_loss = 0.0
    train_r2 = 0.0

    test_loss = 0.0
    test_kl_loss = 0.0
    test_recon_loss = 0.0
    test_label_loss = 0.0
    test_r2 = 0.0

    model.train()
    for (x, c, y) in zip(x_train, conditional_train, y_train):
        # Convert to tensors
        x = torch.FloatTensor(x).unsqueeze(1).to(DEVICE)
        c = torch.FloatTensor(c).to(DEVICE)
        y = torch.FloatTensor(y).to(DEVICE)

        # Get predictions
        out, mean, logvar, pz_mean, r_mean, r_logvar = model(x, c)

        # Remove the conditional from x
        x = x.squeeze(1)[:, :len(df_sensor[0].columns)]

        # Get loss and update
        optimizer.zero_grad()
        loss, kl_loss, recon_loss, label_loss = loss_fn(out, x, mean, logvar, 1, pz_mean, r_mean, r_logvar, y)
        loss.backward()
        optimizer.step()
    
        # Update losses
        train_loss += loss.item()
        train_kl_loss += kl_loss.item()
        train_recon_loss += recon_loss.item()
        train_label_loss += label_loss.item()
        train_r2 += r2_score(y.detach().cpu().numpy(), r_mean.detach().cpu().numpy())

    model.eval()
    with torch.no_grad():
        for (x, c, y) in zip(x_test, conditional_test, y_test):
            # Convert to tensors
            x = torch.FloatTensor(x).unsqueeze(1).to(DEVICE)
            c = torch.FloatTensor(c).to(DEVICE)
            y = torch.FloatTensor(y).to(DEVICE)

            # Get predictions
            out, mean, logvar, pz_mean, r_mean, r_logvar = model(x, c)

            # Remove the conditional from x
            x = x.squeeze(1)[:, :len(df_sensor[0].columns)]

            # Get loss
            loss, kl_loss, recon_loss, label_loss = loss_fn(out, x, mean, logvar, 1, pz_mean, r_mean, r_logvar, y)
        
            # Update losses
            test_loss += loss.item()
            test_kl_loss += kl_loss.item()
            test_recon_loss += recon_loss.item()
            test_label_loss += label_loss.item()
            test_r2 += r2_score(y.detach().cpu().numpy(), r_mean.detach().cpu().numpy())

    

    train_loss /= len(x_train)
    train_kl_loss /= len(x_train)
    train_recon_loss /= len(x_train)
    train_label_loss /= len(x_train)
    train_r2 /= len(x_train)

    test_loss /= len(x_test)
    test_kl_loss /= len(x_test)
    test_recon_loss /= len(x_test)
    test_label_loss /= len(x_test)
    test_r2 /= len(x_test)
    
    print(f"Epoch: {epoch+1}/{EPOCHS}")
    print(f"Train loss: {train_loss:.4f} | Recon loss: {train_recon_loss:.4f} | KL loss: {train_kl_loss:.4f} | Label loss: {train_label_loss:.4f}")
    print(f"Test loss: {test_loss:.4f} | Recon loss: {test_recon_loss:.4f} | KL loss: {test_kl_loss:.4f} | Label loss: {test_label_loss:.4f}")
    print(f"Train R2: {train_r2:.4f}")
    print(f"Test R2: {test_r2:.4f}")
# Out:
# Epoch: 1/200
# Train loss: 2.4540 | Recon loss: 1.0315 | KL loss: 0.3544 | Label loss: 1.0681
# Test loss: 2.1024 | Recon loss: 1.0184 | KL loss: 0.3212 | Label loss: 0.7628
# Train R2: -0.8131
# Test R2: -0.3210
# Epoch: 2/200
# Train loss: 1.9663 | Recon loss: 1.0106 | KL loss: 0.2981 | Label loss: 0.6576
# Test loss: 1.8048 | Recon loss: 1.0025 | KL loss: 0.2705 | Label loss: 0.5318
# Train R2: -0.2628
# Test R2: -0.0017
# Epoch: 3/200
# Train loss: 1.6544 | Recon loss: 0.9836 | KL loss: 0.2601 | Label loss: 0.4107
# Test loss: 1.5882 | Recon loss: 0.9600 | KL loss: 0.2482 | Label loss: 0.3799
# Train R2: 0.0986
# Test R2: 0.2030
# Epoch: 4/200
# Train loss: 1.3694 | Recon loss: 0.9048 | KL loss: 0.2340 | Label loss: 0.2305
# Test loss: 1.3785 | Recon loss: 0.8808 | KL loss: 0.2241 | Label loss: 0.2735
# Train R2: 0.3391
# Test R2: 0.3283
# Epoch: 5/200
# Train loss: 1.0769 | Recon loss: 0.7716 | KL loss: 0.2150 | Label loss: 0.0903
# Test loss: 1.2071 | Recon loss: 0.7960 | KL loss: 0.2022 | Label loss: 0.2089
# Train R2: 0.4877
# Test R2: 0.3959
# Epoch: 6/200
# Train loss: 0.8946 | Recon loss: 0.7152 | KL loss: 0.1928 | Label loss: -0.0134
# Test loss: 1.1229 | Recon loss: 0.7708 | KL loss: 0.1767 | Label loss: 0.1754
# Train R2: 0.5729
# Test R2: 0.4390
# Epoch: 7/200
# Train loss: 0.7666 | Recon loss: 0.6961 | KL loss: 0.1669 | Label loss: -0.0964
# Test loss: 1.0737 | Recon loss: 0.7642 | KL loss: 0.1538 | Label loss: 0.1558
# Train R2: 0.6301
# Test R2: 0.4760
# Epoch: 8/200
# Train loss: 0.6603 | Recon loss: 0.6874 | KL loss: 0.1433 | Label loss: -0.1704
# Test loss: 1.0377 | Recon loss: 0.7590 | KL loss: 0.1318 | Label loss: 0.1469
# Train R2: 0.6745
# Test R2: 0.5100
# Epoch: 9/200
# Train loss: 0.5667 | Recon loss: 0.6821 | KL loss: 0.1225 | Label loss: -0.2380
# Test loss: 1.0105 | Recon loss: 0.7469 | KL loss: 0.1169 | Label loss: 0.1466
# Train R2: 0.7120
# Test R2: 0.5428
# Epoch: 10/200
# Train loss: 0.4842 | Recon loss: 0.6779 | KL loss: 0.1052 | Label loss: -0.2988
# Test loss: 0.9928 | Recon loss: 0.7427 | KL loss: 0.1005 | Label loss: 0.1496
# Train R2: 0.7437
# Test R2: 0.5734
# Epoch: 11/200
# Train loss: 0.4100 | Recon loss: 0.6720 | KL loss: 0.0907 | Label loss: -0.3527
# Train R2: 0.8903
# Test R2: 0.7085
# Epoch: 48/200
# Train loss: -0.2619 | Recon loss: 0.5358 | KL loss: 0.0269 | Label loss: -0.8247
# Test loss: 1.8174 | Recon loss: 0.6203 | KL loss: 0.0370 | Label loss: 1.1601
# Train R2: 0.8907
# Test R2: 0.7089
# Epoch: 49/200
# Train loss: -0.2684 | Recon loss: 0.5327 | KL loss: 0.0272 | Label loss: -0.8282
# Test loss: 1.8653 | Recon loss: 0.6186 | KL loss: 0.0366 | Label loss: 1.2101
# Train R2: 0.8911
# Test R2: 0.7095
# Epoch: 50/200
# Train loss: -0.2752 | Recon loss: 0.5290 | KL loss: 0.0275 | Label loss: -0.8316
# Test loss: 1.9125 | Recon loss: 0.6142 | KL loss: 0.0365 | Label loss: 1.2618
# Train R2: 0.8915
# Test R2: 0.7099
# Epoch: 51/200
# Train loss: -0.2814 | Recon loss: 0.5257 | KL loss: 0.0279 | Label loss: -0.8350
# Test loss: 1.9620 | Recon loss: 0.6106 | KL loss: 0.0366 | Label loss: 1.3148
# Train R2: 0.8919
# Test R2: 0.7104
# Epoch: 52/200
# Train loss: -0.2878 | Recon loss: 0.5222 | KL loss: 0.0282 | Label loss: -0.8382
# Test loss: 2.0123 | Recon loss: 0.6069 | KL loss: 0.0365 | Label loss: 1.3688
# Train R2: 0.8923
# Test R2: 0.7108
# Epoch: 53/200
# Train loss: -0.2941 | Recon loss: 0.5186 | KL loss: 0.0286 | Label loss: -0.8413
# Test loss: 2.0634 | Recon loss: 0.6036 | KL loss: 0.0372 | Label loss: 1.4227
# Train R2: 0.8927
# Test R2: 0.7112
# Epoch: 54/200
# Train loss: -0.2993 | Recon loss: 0.5162 | KL loss: 0.0289 | Label loss: -0.8444
# Test loss: 2.1174 | Recon loss: 0.6036 | KL loss: 0.0366 | Label loss: 1.4772
# Train R2: 0.8930
# Test R2: 0.7116
# Epoch: 55/200
# Train loss: -0.3055 | Recon loss: 0.5125 | KL loss: 0.0293 | Label loss: -0.8474
# Test loss: 2.1654 | Recon loss: 0.5999 | KL loss: 0.0366 | Label loss: 1.5289
# Train R2: 0.8934
# Test R2: 0.7120
# Epoch: 56/200
# Train loss: -0.3117 | Recon loss: 0.5089 | KL loss: 0.0297 | Label loss: -0.8503
# Test loss: 2.2157 | Recon loss: 0.5988 | KL loss: 0.0368 | Label loss: 1.5801
# Train R2: 0.8937
# Test R2: 0.7126
# Epoch: 57/200
# Train loss: -0.3167 | Recon loss: 0.5064 | KL loss: 0.0300 | Label loss: -0.8532
# Test loss: 2.2687 | Recon loss: 0.5950 | KL loss: 0.0368 | Label loss: 1.6369
# Train R2: 0.8940
# Test R2: 0.7128
# Epoch: 58/200
# Train loss: -0.3222 | Recon loss: 0.5032 | KL loss: 0.0305 | Label loss: -0.8559
# Test loss: 2.3208 | Recon loss: 0.5921 | KL loss: 0.0370 | Label loss: 1.6917
# Train R2: 0.8944
# Test R2: 0.7131
# Epoch: 59/200
# Train loss: -0.3276 | Recon loss: 0.5002 | KL loss: 0.0308 | Label loss: -0.8586
# Test loss: 2.3727 | Recon loss: 0.5886 | KL loss: 0.0375 | Label loss: 1.7466
# Train R2: 0.8947
# Test R2: 0.7135
# Epoch: 60/200
# Train loss: -0.3330 | Recon loss: 0.4971 | KL loss: 0.0312 | Label loss: -0.8613
# Test loss: 2.4274 | Recon loss: 0.5917 | KL loss: 0.0373 | Label loss: 1.7984
# Train R2: 0.8950
# Test R2: 0.7139
# Epoch: 61/200
# Train loss: -0.3382 | Recon loss: 0.4942 | KL loss: 0.0315 | Label loss: -0.8639
# Test loss: 2.4738 | Recon loss: 0.5835 | KL loss: 0.0372 | Label loss: 1.8530
# Train R2: 0.8953
# Test R2: 0.7143
# Epoch: 62/200
# Train loss: -0.3428 | Recon loss: 0.4918 | KL loss: 0.0319 | Label loss: -0.8665
# Test loss: 2.5193 | Recon loss: 0.5743 | KL loss: 0.0368 | Label loss: 1.9082
# Train R2: 0.8956
# Test R2: 0.7146
# Epoch: 63/200
# Train loss: -0.3489 | Recon loss: 0.4879 | KL loss: 0.0322 | Label loss: -0.8690
# Test loss: 2.5749 | Recon loss: 0.5728 | KL loss: 0.0377 | Label loss: 1.9645
# Train R2: 0.8959
# Test R2: 0.7148
# Epoch: 64/200
# Train loss: -0.3527 | Recon loss: 0.4863 | KL loss: 0.0325 | Label loss: -0.8715
# Test loss: 2.6308 | Recon loss: 0.5738 | KL loss: 0.0369 | Label loss: 2.0200
# Train R2: 0.8962
# Test R2: 0.7150
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-76-4a3fb0f889c5> in <module>
#      21
#      22         # Get predictions
# ---> 23         out, mean, logvar, pz_mean, r_mean, r_logvar = model(x, c)
#      24
#      25         # Remove the conditional from x
#
# ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-65-d7b560f98b94> in forward(self, x, conditional)
#      82
#      83         # decode
# ---> 84         x = self.decoder(z1.unsqueeze(1))
#      85
#      86         return x, mean, logvar, pz_mean, r_mean, r_logvar
#
# ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-65-d7b560f98b94> in forward(self, x)
#      63
#      64     def forward(self, x):
# ---> 65         outputs, (h, c) = self.rnn(x)
#      66         outputs = outputs.squeeze(1)
#      67         return self.rnn_to_output(outputs) #shape=(seq_len, num_dir * output_features)
#
# ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/pytorch/lib/python3.9/site-packages/torch/nn/modules/rnn.py in forward(self, input, hx)
#     659         self.check_forward_args(input, hx, batch_sizes)
#     660         if batch_sizes is None:
# --> 661             result = _VF.lstm(input, hx, self._flat_weights, self.bias, self.num_layers,
#     662                               self.dropout, self.training, self.bidirectional, self.batch_first)
#     663         else:
#
# KeyboardInterrupt:

# %%
x1 = torch.FloatTensor(x_train[0]).unsqueeze(1).to(DEVICE)
c1 = torch.FloatTensor(conditional_train[0]).to(DEVICE)

x2 = torch.FloatTensor(x_train[20]).unsqueeze(1).to(DEVICE)
c2 = torch.FloatTensor(conditional_train[20]).to(DEVICE)



out1, mean1, logvar1, _, _, _ = model(x1, c1)
out2, mean2, logvar2, _, _ , _  = model(x2, c2)

# %%
# Out:
# torch.Size([6210, 8])

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
mean = pca.fit_transform(torch.cat([mean1,mean2]).detach().cpu())

# %%
from plotly import graph_objects as go

fig = go.Figure()

fig.add_trace(go.Scatter(x=mean[:1095,0], y=mean[:1095,1],
                    mode='markers',
                    name='Site 0', 
                    marker=dict(size=3)))
fig.add_trace(go.Scatter(x=mean[1095:,0], y=mean[1095:,1],
                    mode='markers',
                    name='Site 20', 
                    marker=dict(size=3)))
# Out:
# <div>                            <div id="670dd83e-c6ce-49f7-b427-40d92deb316f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("